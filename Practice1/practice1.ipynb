# %% [markdown]
# # Практичне Завдання 1
# ### Студента Групи МІТ-31
# ### Фітя Владислава Тарасовича
#
# ### **Стовпці = ["x1", "x4", "x7", "x9"]**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mat
import seaborn as sea

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("practice1_data.csv")
data.head(19)
# Out:
#           x1        x2        x3        x4        x5        x6        x7  \
# 0   2.163950  0.015729 -1.136593  2.182571 -1.552051 -0.909067  1.791084
# 1   1.364464 -1.359741 -1.881798 -0.484231 -1.974301 -0.017010  2.184909
# 2   1.237133  0.945965 -0.008633  0.889645  0.348132 -1.863290 -1.093229
# 3   0.530019  2.739019  1.168152 -0.182967 -0.313546  1.274500  1.097952
# 4  -1.169403 -0.387841  0.049067 -2.136358 -1.839488 -0.635955 -0.136341
# 5   2.632567 -2.187044 -2.877435  1.214570 -0.932406 -1.751738 -0.371274
# 6   0.414880 -0.157428  1.192164  1.315924 -1.487844 -1.530894 -1.467259
# 7   0.696428  2.336794  0.937671 -1.408921  0.986726  1.651799  2.112990
# 8  -2.011219 -0.851366  1.213547  1.393759  0.387996  1.605899  2.790490
# 9  -0.584189 -3.062913 -1.940569 -0.740922 -0.147745 -0.961257  1.870423
# 10 -1.187890 -1.331656 -0.844400  0.386570  1.384259 -0.294298 -0.332678
# 11 -1.230475 -0.020875 -0.478433 -0.064970  0.065805 -0.816994 -1.284032
# 12 -0.271275 -1.712766 -0.938493 -0.698833 -1.276602  1.096345  0.907509
# 13  1.457550  1.355220  1.878332 -0.594132 -0.446533 -1.001015 -0.076966
# 14  0.388975 -0.969359 -1.198454  0.171409 -2.354015  1.235428 -1.772474
# 15  1.162111 -0.997523  0.622846 -1.824711 -0.264147 -1.188826 -1.412415
# 16  1.702438  2.433166  2.121757 -1.189441 -0.579986 -0.850053  1.484688
# 17  3.360343  0.553506 -1.043801  0.762330  1.410152 -1.002868 -1.480138
# 18  1.937279  0.272505 -1.129977  0.985143 -0.144330 -0.115907  0.878134
#
#           x8        x9       x10  classes
# 0  -1.094894  0.308272 -0.912365        0
# 1  -1.012308 -0.774774 -3.702803        0
# 2   0.057705  1.646754 -0.834884        2
# 3  -0.909685  1.490564  2.300722        1
# 4   0.357952 -0.376029 -2.323494        2
# 5  -1.623788 -0.593950  0.666200        0
# 6   2.600887  0.714335 -0.527407        2
# 7  -1.268736  0.751079  3.482437        0
# 8   1.318649 -2.263388 -0.265534        2
# 9  -0.814882 -2.945417 -1.376556        0
# 10 -1.185948 -1.749923  3.076156        1
# 11 -0.745694  0.115631 -1.530162        1
# 12  0.034400 -1.413349 -1.915779        2
# 13  2.489635  1.687658 -0.148617        3
# 14 -0.460005  0.105402 -0.560449        1
# 15  2.604718  0.285763  0.161369        2
# 16  1.577758  1.879574  0.767617        3
# 17 -0.413404  2.195203 -0.054960        3
# 18 -1.343620  0.624823 -0.245936        0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   x1       1500 non-null   float64
#  1   x2       1500 non-null   float64
#  2   x3       1500 non-null   float64
#  3   x4       1500 non-null   float64
#  4   x5       1500 non-null   float64
#  5   x6       1500 non-null   float64
#  6   x7       1500 non-null   float64
#  7   x8       1500 non-null   float64
#  8   x9       1500 non-null   float64
#  9   x10      1500 non-null   float64
#  10  classes  1500 non-null   int64
# dtypes: float64(10), int64(1)
# memory usage: 129.0 KB

# %%
dropCollumns = ["x2", "x3", "x5", "x6", "x8", "x10"]

for i in range(len(dropCollumns)):
    data=data.drop(dropCollumns[i], axis=1)

print("==============Describe===============")
data.describe()
# Out:
# ==============Describe===============
#                 x1           x4           x7           x9      classes
# count  1500.000000  1500.000000  1500.000000  1500.000000  1500.000000
# mean      0.550329    -0.017770     0.056311    -0.083342     1.497333
# std       1.489842     0.976437     1.560251     1.623737     1.117807
# min      -4.857101    -3.402785    -4.975684    -5.973969     0.000000
# 25%      -0.437339    -0.631979    -1.112853    -1.167791     0.000000
# 50%       0.601106     0.009628    -0.064162    -0.119206     1.000000
# 75%       1.566922     0.625042     1.215963     0.886031     2.000000
# max       5.147879     3.357813     4.344007     6.945688     3.000000

# %%
print("==============Value Counts===============")
data["classes"].value_counts()
# Out:
# ==============Value Counts===============
# 0    376
# 2    376
# 1    375
# 3    373
# Name: classes, dtype: int64

# %%
fig, axes = mat.subplots(2, 2, figsize=(10,5), dpi = 100)
fig.suptitle('Distribution per classes')

def Kdeplot(axes, data, label, hue, alpha):
    sea.kdeplot(ax = axes, data = data, x = label, hue = hue, alpha = alpha, shade = True)
    axes.set_xlabel(label)
    axes.get_legend().remove()

Kdeplot(axes[0,0], data, "x1", "classes", 0.5)
Kdeplot(axes[0,1], data, "x4", "classes", 0.5)
Kdeplot(axes[1,0], data, "x7", "classes", 0.2)
Kdeplot(axes[1,1], data, "x9", "classes", 0.5)

mat.tight_layout()

# %%
fig, axes = mat.subplots(1, 2, figsize=(19,3), dpi = 100)
fig.suptitle("Classes data")


def Scatterplot(axes, data, x, y, hue):
    sea.scatterplot(ax=axes, data = data, x = x, y = y, hue = hue)
    axes.set_xlabel(x)
    axes.set_ylabel(y)


Scatterplot(axes[0], data, 'x1', 'x4', "classes")
Scatterplot(axes[1], data, 'x7', 'x9', "classes")

# %%
fig, axes = mat.subplots(2, 2, figsize=(10,5), dpi = 100)

def Boxplot(axes, data, x, y, title):
    sea.boxplot(ax=axes, data=data, x=x, y=y)
    axes.set_xlabel(None)
    axes.set_ylabel(None)
    axes.set_title(title)

Boxplot(axes[0,0], data, "classes", 'x1', "Mean x1")
Boxplot(axes[0,1], data, "classes", 'x4', "Mean x4")
Boxplot(axes[1,0], data, "classes", 'x7', "Mean x7")
Boxplot(axes[1,1], data, "classes", 'x9', "Mean x9")


mat.tight_layout()
mat.subplots_adjust(hspace=0.5)

# %%
mat.figure(figsize = (8, 4), dpi = 100)
sea.heatmap(data.corr(), annot = True, cmap = "Oranges", vmin = -1, vmax = 1)
mat.title("Correlation map")
mat.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, plot_confusion_matrix, classification_report


x = data.drop("classes", axis = 1)
y = data["classes"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=101)

scaler = StandardScaler()
log_model = LogisticRegression()

Scaled_x_train = scaler.fit_transform(x_train)
Scaled_x_test = scaler.transform(x_test)
log_model.fit(Scaled_x_train, y_train)
y_pred = log_model.predict(Scaled_x_test)

confusion_matrix(y_test, y_pred)

fig, ax = mat.subplots(dpi = 120)
plot_confusion_matrix(log_model, Scaled_x_test, y_test, ax = ax, cmap="inferno");
# Out:
# Hello0       0
# 1       0
# 2       2
# 3       1
# 4       2
#        ..
# 1495    1
# 1496    3
# 1497    1
# 1498    2
# 1499    3
# Name: classes, Length: 1500, dtype: int64

# %%
score = accuracy_score(y_test, y_pred)
round(score, 2)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.49      0.50        74
#            1       0.57      0.74      0.64        73
#            2       0.44      0.41      0.43        68
#            3       0.58      0.49      0.53        85
#
#     accuracy                           0.53       300
#    macro avg       0.53      0.53      0.53       300
# weighted avg       0.53      0.53      0.53       300
